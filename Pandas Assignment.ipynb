# %%
import numpy as np
import pandas as pd
import csv
import json
import html
import pickle
import glob
import re
import matplotlib.pyplot as plt

# %% [markdown]
# # PART 1

# %%
files=glob.glob("D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment/*csv")
for file in files:
    print(file)
# Out:
# D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\inventory.csv
# D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states0.csv
# D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states1.csv
# D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states2.csv
# D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states3.csv
# D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states4.csv
# D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states5.csv
# D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states6.csv
# D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states7.csv
# D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states8.csv
# D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states9.csv

# %%
df1=pd.read_csv("D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states0.csv")
df2=pd.read_csv("D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states1.csv")
df3=pd.read_csv("D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states2.csv")
df4=pd.read_csv("D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states3.csv")
df5=pd.read_csv("D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states4.csv")
df6=pd.read_csv("D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states5.csv")
df7=pd.read_csv("D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states6.csv")
df8=pd.read_csv("D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states7.csv")
df9=pd.read_csv("D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states8.csv")
df10=pd.read_csv("D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\states9.csv")

# %%
columns_names=["State","TotalPop","Hispanic","White","Black","Native","Asian","Pacific","Income","GenderPop"]

# %%
df_1=pd.DataFrame(df1,columns=columns_names)
df_2=pd.DataFrame(df2,columns=columns_names)
df_3=pd.DataFrame(df3,columns=columns_names)
df_4=pd.DataFrame(df4,columns=columns_names)
df_5=pd.DataFrame(df5,columns=columns_names)
df_6=pd.DataFrame(df6,columns=columns_names)
df_7=pd.DataFrame(df7,columns=columns_names)
df_8=pd.DataFrame(df8,columns=columns_names)
df_9=pd.DataFrame(df9,columns=columns_names)
df_10=pd.DataFrame(df10,columns=columns_names)

# %%
us_census=pd.concat([df_1,df_2,df_3,df_4,df_5,df_6,df_7,df_8,df_9,df_10],ignore_index=True)

# %%
display(us_census)
# Out:
#                    State  TotalPop             Hispanic                White  \
# 0                Alabama   4830620                3.75%               61.88%
# 1                 Alaska    733375                5.91%               60.91%
# 2                Arizona   6641928               29.57%               57.12%
# 3               Arkansas   2958208                6.22%               71.14%
# 4             California  38421464               37.29%               40.22%
# 5               Colorado   5278906               20.78%               69.90%
# 6               Colorado   5278906   20.78438003220608%   69.89557165861504%
# 7            Connecticut   3593222  15.604830917874388%    67.6770531400966%
# 8               Delaware    926454    8.82476635514019%   64.63271028037383%
# 9   District of Columbia    647484   9.165921787709499%  33.103910614525134%
# 10               Florida  19645772    21.3385426653884%   59.08374880153398%
# ...

# %%
us_census.columns
# Out:
# Index(['State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian',
#        'Pacific', 'Income', 'GenderPop'],
#       dtype='object')

# %%
us_census.dtypes
# Out:
# State        object
# TotalPop      int64
# Hispanic     object
# White        object
# Black        object
# Native       object
# Asian        object
# Pacific      object
# Income       object
# GenderPop    object
# dtype: object

# %%
us_census.head()
# Out:
#         State  TotalPop Hispanic   White   Black  Native   Asian Pacific  \
# 0     Alabama   4830620    3.75%  61.88%  31.25%   0.45%   1.05%   0.03%
# 1      Alaska    733375    5.91%  60.91%   2.85%  16.39%   5.45%   1.06%
# 2     Arizona   6641928   29.57%  57.12%   3.85%   4.36%   2.88%   0.17%
# 3    Arkansas   2958208    6.22%  71.14%  18.97%   0.52%   1.14%   0.15%
# 4  California  38421464   37.29%  40.22%   5.68%   0.41%  13.05%   0.35%
#
#                Income            GenderPop
# 0  $43296.35860306644    2341093M_2489527F
# 1  $70354.74390243902      384160M_349215F
# 2  $54207.82095490716    3299088M_3342840F
# 3  $41935.63396778917    1451913M_1506295F
# 4  $67264.78230266465  19087135M_19334329F

# %%
patteren = re.compile(r'[^\d\.]')

# %%
us_census["Income"] = [patteren.sub("",x) for x in us_census["Income"]]

# %%
us_census["Income"]=us_census["Income"].astype(float)

# %%
us_census.head()
# Out:
#         State  TotalPop Hispanic   White   Black  Native   Asian Pacific  \
# 0     Alabama   4830620    3.75%  61.88%  31.25%   0.45%   1.05%   0.03%
# 1      Alaska    733375    5.91%  60.91%   2.85%  16.39%   5.45%   1.06%
# 2     Arizona   6641928   29.57%  57.12%   3.85%   4.36%   2.88%   0.17%
# 3    Arkansas   2958208    6.22%  71.14%  18.97%   0.52%   1.14%   0.15%
# 4  California  38421464   37.29%  40.22%   5.68%   0.41%  13.05%   0.35%
#
#          Income            GenderPop
# 0  43296.358603    2341093M_2489527F
# 1  70354.743902      384160M_349215F
# 2  54207.820955    3299088M_3342840F
# 3  41935.633968    1451913M_1506295F
# 4  67264.782303  19087135M_19334329F

# %%
us_census[["Men","Women"]]=us_census.GenderPop.str.split("_",expand=True)

# %%
us_census.head()
# Out:
#         State  TotalPop Hispanic   White   Black  Native   Asian Pacific  \
# 0     Alabama   4830620    3.75%  61.88%  31.25%   0.45%   1.05%   0.03%
# 1      Alaska    733375    5.91%  60.91%   2.85%  16.39%   5.45%   1.06%
# 2     Arizona   6641928   29.57%  57.12%   3.85%   4.36%   2.88%   0.17%
# 3    Arkansas   2958208    6.22%  71.14%  18.97%   0.52%   1.14%   0.15%
# 4  California  38421464   37.29%  40.22%   5.68%   0.41%  13.05%   0.35%
#
#          Income            GenderPop        Men      Women
# 0  43296.358603    2341093M_2489527F   2341093M   2489527F
# 1  70354.743902      384160M_349215F    384160M    349215F
# 2  54207.820955    3299088M_3342840F   3299088M   3342840F
# 3  41935.633968    1451913M_1506295F   1451913M   1506295F
# 4  67264.782303  19087135M_19334329F  19087135M  19334329F

# %%
patteren_2 = re.compile(r'[^\d]')

# %%
us_census["Men"] = [patteren_2.sub("",x) for x in us_census["Men"]]
us_census["Women"] = [patteren_2.sub("",x) for x in us_census["Women"]]

# %%
us_census.head()
# Out:
#         State  TotalPop Hispanic   White   Black  Native   Asian Pacific  \
# 0     Alabama   4830620    3.75%  61.88%  31.25%   0.45%   1.05%   0.03%
# 1      Alaska    733375    5.91%  60.91%   2.85%  16.39%   5.45%   1.06%
# 2     Arizona   6641928   29.57%  57.12%   3.85%   4.36%   2.88%   0.17%
# 3    Arkansas   2958208    6.22%  71.14%  18.97%   0.52%   1.14%   0.15%
# 4  California  38421464   37.29%  40.22%   5.68%   0.41%  13.05%   0.35%
#
#          Income            GenderPop       Men     Women
# 0  43296.358603    2341093M_2489527F   2341093   2489527
# 1  70354.743902      384160M_349215F    384160    349215
# 2  54207.820955    3299088M_3342840F   3299088   3342840
# 3  41935.633968    1451913M_1506295F   1451913   1506295
# 4  67264.782303  19087135M_19334329F  19087135  19334329

# %%
us_census.loc[:,["State","Women"]]
# Out:
#                    State     Women
# 0                Alabama   2489527
# 1                 Alaska    349215
# 2                Arizona   3342840
# 3               Arkansas   1506295
# 4             California  19334329
# 5               Colorado   2630239
# 6               Colorado   2630239
# 7            Connecticut   1841615
# 8               Delaware    478041
# 9   District of Columbia    340810
# 10               Florida  10045763
# 11               Georgia   5123362
# 12               Georgia   5123362
# 13                Hawaii    696428
# 14                 Idaho    806083
# 15              Illinois   6556862
# 16               Indiana   3333382
# 17                  Iowa   1558931
# 18                  Iowa   1558931
# 19                Kansas   1453125
# 20              Kentucky   2233145
# 21             Louisiana   2364097
# 22                 Maine    679019
# 23              Maryland
# 24              Maryland
# 25         Massachusetts   3455936
# ...

# %%
us_census["Men"]=us_census["Men"].astype(int)

# %%
patteren_3=re.compile(r"^\s*$")

# %%
us_census["Women"].replace(patteren_3,np.nan,regex=True,inplace=True)

# %%
filler=us_census["TotalPop"]-us_census["Men"]

# %%
us_census["Women"].fillna(filler,inplace=True)

# %%
us_census["Women"]=us_census["Women"].astype(int)

# %%
us_census
# Out:
#                    State  TotalPop             Hispanic                White  \
# 0                Alabama   4830620                3.75%               61.88%
# 1                 Alaska    733375                5.91%               60.91%
# 2                Arizona   6641928               29.57%               57.12%
# 3               Arkansas   2958208                6.22%               71.14%
# 4             California  38421464               37.29%               40.22%
# 5               Colorado   5278906               20.78%               69.90%
# 6               Colorado   5278906   20.78438003220608%   69.89557165861504%
# 7            Connecticut   3593222  15.604830917874388%    67.6770531400966%
# 8               Delaware    926454    8.82476635514019%   64.63271028037383%
# 9   District of Columbia    647484   9.165921787709499%  33.103910614525134%
# 10               Florida  19645772    21.3385426653884%   59.08374880153398%
# ...

# %%
us_census.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42     True
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48     True
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54     True
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# dtype: bool

# %%
us_census.drop_duplicates()
# Out:
#                    State  TotalPop             Hispanic                White  \
# 0                Alabama   4830620                3.75%               61.88%
# 1                 Alaska    733375                5.91%               60.91%
# 2                Arizona   6641928               29.57%               57.12%
# 3               Arkansas   2958208                6.22%               71.14%
# 4             California  38421464               37.29%               40.22%
# 5               Colorado   5278906               20.78%               69.90%
# 6               Colorado   5278906   20.78438003220608%   69.89557165861504%
# 7            Connecticut   3593222  15.604830917874388%    67.6770531400966%
# 8               Delaware    926454    8.82476635514019%   64.63271028037383%
# 9   District of Columbia    647484   9.165921787709499%  33.103910614525134%
# 10               Florida  19645772    21.3385426653884%   59.08374880153398%
# ...

# %%
x=us_census["Women"]
y=us_census["Income"]

# %%
plt.scatter(x,y)
plt.show()

# %%
us_census.columns
# Out:
# Index(['State', 'TotalPop', 'Hispanic', 'White', 'Black', 'Native', 'Asian',
#        'Pacific', 'Income', 'GenderPop', 'Men', 'Women'],
#       dtype='object')

# %%
us_census.dtypes
# Out:
# State         object
# TotalPop       int64
# Hispanic      object
# White         object
# Black         object
# Native        object
# Asian         object
# Pacific       object
# Income       float64
# GenderPop     object
# Men            int32
# Women          int32
# dtype: object

# %%
us_census["Hispanic"] = [patteren.sub("",x) for x in us_census["Hispanic"]]
us_census["White"] = [patteren.sub("",x) for x in us_census["White"]]
us_census["Black"] = [patteren.sub("",x) for x in us_census["Black"]]
us_census["Native"] = [patteren.sub("",x) for x in us_census["Native"]]
us_census["Asian"] = [patteren.sub("",x) for x in us_census["Asian"]]

# %%
us_census["Hispanic"] = us_census["Hispanic"].astype(float)
us_census["White"] = us_census["White"].astype(float)
us_census["Black"] = us_census["Black"].astype(float)
us_census["Native"] = us_census["Native"].astype(float)
us_census["Asian"] = us_census["Asian"].astype(float)

# %%
us_census.dtypes
# Out:
# State         object
# TotalPop       int64
# Hispanic     float64
# White        float64
# Black        float64
# Native       float64
# Asian        float64
# Pacific       object
# Income       float64
# GenderPop     object
# Men            int32
# Women          int32
# dtype: object

# %%
us_census
# Out:
#                    State  TotalPop   Hispanic      White      Black  \
# 0                Alabama   4830620   3.750000  61.880000  31.250000
# 1                 Alaska    733375   5.910000  60.910000   2.850000
# 2                Arizona   6641928  29.570000  57.120000   3.850000
# 3               Arkansas   2958208   6.220000  71.140000  18.970000
# 4             California  38421464  37.290000  40.220000   5.680000
# 5               Colorado   5278906  20.780000  69.900000   3.550000
# 6               Colorado   5278906  20.784380  69.895572   3.546377
# 7            Connecticut   3593222  15.604831  67.677053  10.348068
# 8               Delaware    926454   8.824766  64.632710  20.743925
# 9   District of Columbia    647484   9.165922  33.103911  51.776536
# 10               Florida  19645772  21.338543  59.083749  15.165676
# 11               Georgia  10006693   8.418242  54.286306  32.088298
# 12               Georgia  10006693   8.418242  54.286306  32.088298
# ...

# %%
us_census.dtypes
# Out:
# State         object
# TotalPop       int64
# Hispanic     float64
# White        float64
# Black        float64
# Native       float64
# Asian        float64
# Pacific       object
# Income       float64
# GenderPop     object
# Men            int32
# Women          int32
# dtype: object

# %%
patteren_4=re.compile(r"[/%]")

# %%
us_census["Pacific"] =us_census["Pacific"].str.replace(patteren_4,"").astype(float)

# %%
filler_2=us_census["Pacific"].mean()

# %%
us_census["Pacific"].fillna(filler_2, inplace=True)

# %%
us_census
# Out:
#                    State  TotalPop   Hispanic      White      Black  \
# 0                Alabama   4830620   3.750000  61.880000  31.250000
# 1                 Alaska    733375   5.910000  60.910000   2.850000
# 2                Arizona   6641928  29.570000  57.120000   3.850000
# 3               Arkansas   2958208   6.220000  71.140000  18.970000
# 4             California  38421464  37.290000  40.220000   5.680000
# 5               Colorado   5278906  20.780000  69.900000   3.550000
# 6               Colorado   5278906  20.784380  69.895572   3.546377
# 7            Connecticut   3593222  15.604831  67.677053  10.348068
# 8               Delaware    926454   8.824766  64.632710  20.743925
# 9   District of Columbia    647484   9.165922  33.103911  51.776536
# 10               Florida  19645772  21.338543  59.083749  15.165676
# 11               Georgia  10006693   8.418242  54.286306  32.088298
# 12               Georgia  10006693   8.418242  54.286306  32.088298
# ...

# %%
us_census.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12     True
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18     True
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24     True
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30     True
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36     True
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42     True
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48     True
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54     True
# 55    False
# 56    False
# 57    False
# 58    False
# 59    False
# dtype: bool

# %%
us_census=us_census.drop_duplicates()

# %%
us_census
# Out:
#                    State  TotalPop   Hispanic      White      Black  \
# 0                Alabama   4830620   3.750000  61.880000  31.250000
# 1                 Alaska    733375   5.910000  60.910000   2.850000
# 2                Arizona   6641928  29.570000  57.120000   3.850000
# 3               Arkansas   2958208   6.220000  71.140000  18.970000
# 4             California  38421464  37.290000  40.220000   5.680000
# 5               Colorado   5278906  20.780000  69.900000   3.550000
# 6               Colorado   5278906  20.784380  69.895572   3.546377
# 7            Connecticut   3593222  15.604831  67.677053  10.348068
# 8               Delaware    926454   8.824766  64.632710  20.743925
# 9   District of Columbia    647484   9.165922  33.103911  51.776536
# 10               Florida  19645772  21.338543  59.083749  15.165676
# 11               Georgia  10006693   8.418242  54.286306  32.088298
# 13                Hawaii   1406299   9.186709  25.032278   2.052848
# ...

# %%
us_census["Hispanic"].plot.hist()
plt.show()

# %%
us_census["White"].plot.hist()
plt.show()

# %%
us_census["Black"].plot.hist()
plt.show()

# %%
us_census["Native"].plot.hist()
plt.show()

# %%
us_census["Asian"].plot.hist()
plt.show()

# %%
us_census["Pacific"].plot.hist()
plt.show()

# %%
us_census[["Hispanic","White","Black","Native","Asian","Pacific"]].plot.density()
plt.show()

# %%
us_census.plot.bar()
plt.show()

# %%
us_census.plot(x="State",y=["Hispanic","White","Black","Native","Asian","Pacific"],kind="bar")
plt.show()

# %% [markdown]
# # PART 2

# %%
inventory=pd.read_csv("D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment\inventory.csv")

# %%
inventory
# Out:
#          location  product_type         product_description  quantity  price
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
staten_island=inventory.iloc[0:10]

# %%
staten_island
# Out:
#         location  product_type         product_description  quantity  price
# 0  Staten Island         seeds                       daisy         4   6.99
# 1  Staten Island         seeds                  calla lily        46  19.99
# 2  Staten Island         seeds                      tomato        85  13.99
# 3  Staten Island  garden tools                        rake         4  13.99
# 4  Staten Island  garden tools                 wheelbarrow         0  89.99
# 5  Staten Island  garden tools                       spade        93  19.99
# 6  Staten Island  pest_control               insect killer        74  12.99
# 7  Staten Island  pest_control                 weed killer         8  23.99
# 8  Staten Island       planter  20 inch terracotta planter         0  17.99
# 9  Staten Island       planter      8 inch plastic planter        53   3.99

# %%
product_request=staten_island["product_description"]

# %%
product_request
# Out:
# 0                         daisy
# 1                    calla lily
# 2                        tomato
# 3                          rake
# 4                   wheelbarrow
# 5                         spade
# 6                 insect killer
# 7                   weed killer
# 8    20 inch terracotta planter
# 9        8 inch plastic planter
# Name: product_description, dtype: object

# %%
seed_request=inventory[(inventory["location"]=="Brooklyn")&(inventory["product_type"]=="seeds")]

# %%
seed_request
# Out:
#     location product_type product_description  quantity  price
# 10  Brooklyn        seeds               daisy        50   6.99
# 11  Brooklyn        seeds          calla lily         0  19.99
# 12  Brooklyn        seeds              tomato         0  13.99

# %%
inventory["in_stock"]=inventory["quantity"]>0

# %%
inventory
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
inventory["total_value"]=inventory["price"]*inventory["quantity"]

# %%
inventory
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %%
# %load "D:/Q2/Assignments/Pandas/New folder/Assignment/Working assignment/script.py"
combine_lambda = lambda row: \
    '{} - {}'.format(row.product_type,
                     row.product_description)

# %%
combine_lambda = lambda row: \
 "{} - {}".format(row.product_type,
                     row.product_description)

# %%
inventory["full_description"]=inventory[["product_type","product_description"]].apply(combine_lambda,axis=1)

# %%
inventory
# Out:
#          location  product_type         product_description  quantity  price  \
# 0   Staten Island         seeds                       daisy         4   6.99
# 1   Staten Island         seeds                  calla lily        46  19.99
# 2   Staten Island         seeds                      tomato        85  13.99
# 3   Staten Island  garden tools                        rake         4  13.99
# 4   Staten Island  garden tools                 wheelbarrow         0  89.99
# 5   Staten Island  garden tools                       spade        93  19.99
# 6   Staten Island  pest_control               insect killer        74  12.99
# 7   Staten Island  pest_control                 weed killer         8  23.99
# 8   Staten Island       planter  20 inch terracotta planter         0  17.99
# 9   Staten Island       planter      8 inch plastic planter        53   3.99
# 10       Brooklyn         seeds                       daisy        50   6.99
# ...

# %% [markdown]
# # Completed
